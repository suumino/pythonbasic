# %%
#필요한 모듈 설치
# 사진 관련 모듈
# 인터넷 연결 관련 모듈

# !pip install pillow  
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\82108\anaconda3\lib\site-packages (8.0.1)
# Requirement already satisfied: requests in c:\users\82108\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\82108\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\82108\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\82108\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\82108\anaconda3\lib\site-packages (from requests) (3.0.4)

# %%
import matplotlib.pyplot as plt   # 그림 관련
import matplotlib.image as mpimg # 사진 관

# %matplotlib inline

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize = (10,8))
plt.imshow(img)
plt.show()

# %%
# 유명인 얼굴과 얼마나 비슷한지 검색

import requests   # 인터넷 연결

client_id = "pXfdBkFikDiBS8_MgcYQ"
client_secret = "j53WxUOyKj"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg', 'rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "celebrity": {
#                 "value": "김수현",
#                 "confidence": 0.298706
#             }
#         }
#     ]
# }

# %%
# 얼굴 인식, 나이 예측, 감정 분석

import requests  # 인터넷 연결

client_id = "pXfdBkFikDiBS8_MgcYQ"
client_secret = "j53WxUOyKj"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json   # json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 275,
#             "height": 183
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 114,
#                 "y": 56,
#                 "width": 20,
#                 "height": 20
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999725
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.242592
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.684828
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.92016
#             }
#         },
#         {
#             "roi": {
#                 "x": 162,
#                 "y": 25,
#                 "width": 25,
#                 "height": 25
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 171,
#                     "y": 32
#                 },
#                 "rightEye": {
#                     "x": 180,
#                     "y": 32
#                 },
#                 "nose": {
#                     "x": 174,
#                     "y": 38
#                 },
#                 "leftMouth": {
#                     "x": 170,
#                     "y": 42
#                 },
#                 "rightMouth": {
#                     "x": 180,
#                     "y": 42
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.996792
#             },
#             "age": {
#                 "value": "25~29",
#                 "confidence": 0.950213
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.545195
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.824289
#             }
#         },
#         {
#             "roi": {
#                 "x": 85,
#                 "y": 40,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999752
#             },
#             "age": {
#                 "value": "26~30",
#                 "confidence": 0.387025
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.995412
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.837702
#             }
#         },
#         {
#             "roi": {
#                 "x": 154,
#                 "y": 68,
#                 "width": 23,
#                 "height": 23
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.995583
#             },
#             "age": {
#                 "value": "13~17",
#                 "confidence": 0.095429
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.59278
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.950124
#             }
#         }
#     ]
# }

# %%
####################################
# 기본 문법 학습
####################################

# %%
# dict형과 json에 대해...

dict = {'Name':'pinkwink', 'Age':'None', 'Class':['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('Name')
# Out:
# 'pinkwink'

# %%
dict.get('Age', 'nothing')
# Out:
# 'None'

# %%
# json (Java Script Object Notation)

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history':[
        {'data':'2019-03-01', 'log':True},
        {'date':'2019-03-02', 'log':False},
    ]
}

# %%
import json
json_test = json.dumps(customer, indent=4, ensure_ascii=False)
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "data": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %%
#########################
#사진 위에 정보 표시하기
#########################

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize = (10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴 인식, 나이 예측, 감정 분석

import requests  # 인터넷 연결

client_id = "pXfdBkFikDiBS8_MgcYQ"
client_secret = "j53WxUOyKj"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 680,
#             "height": 400
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 272,
#                 "y": 98,
#                 "width": 113,
#                 "height": 113
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 298,
#                     "y": 124
#                 },
#                 "rightEye": {
#                     "x": 350,
#                     "y": 129
#                 },
#                 "nose": {
#                     "x": 320,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 297,
#                     "y": 182
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 186
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999998
#             },
#             "age": {
#                 "value": "30~34",
#                 "confidence": 0.441697
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.991977
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces']
# Out:
# [{'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#   'landmark': {'leftEye': {'x': 298, 'y': 124},
#    'rightEye': {'x': 350, 'y': 129},
#    'nose': {'x': 320, 'y': 157},
#    'leftMouth': {'x': 297, 'y': 182},
#    'rightMouth': {'x': 343, 'y': 186}},
#   'gender': {'value': 'male', 'confidence': 0.999998},
#   'age': {'value': '30~34', 'confidence': 0.441697},
#   'emotion': {'value': 'neutral', 'confidence': 1.0},
#   'pose': {'value': 'frontal_face', 'confidence': 0.991977}}]

# %%
parsed['faces'][0]
# Out:
# {'roi': {'x': 272, 'y': 98, 'width': 113, 'height': 113},
#  'landmark': {'leftEye': {'x': 298, 'y': 124},
#   'rightEye': {'x': 350, 'y': 129},
#   'nose': {'x': 320, 'y': 157},
#   'leftMouth': {'x': 297, 'y': 182},
#   'rightMouth': {'x': 343, 'y': 186}},
#  'gender': {'value': 'male', 'confidence': 0.999998},
#  'age': {'value': '30~34', 'confidence': 0.441697},
#  'emotion': {'value': 'neutral', 'confidence': 1.0},
#  'pose': {'value': 'frontal_face', 'confidence': 0.991977}}

# %%
parsed['faces'][0]['roi']
# Out:
# {'x': 272, 'y': 98, 'width': 113, 'height': 113}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999998}

# %%
parsed['faces'][0]['age']
# Out:
# {'value': '30~34', 'confidence': 0.441697}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x, y, w, h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion, emotion_confi = parsed['faces'][0]['emotion'].values()
age, age_confi = parsed['faces'][0]['age'].values()
print(x)
print(y)
print(w)
print(h)
print(gender)
print(gen_confi)
# Out:
# 272
# 98
# 113
# 113
# male
# 0.999998

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emotion_confi) + '\n' + age + " : " + str(age_confi) + '\n'

# %%
print(annotation)
# Out:
# male : 0.999998
# neutral : 1.0
# 30~34 : 0.441697

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')

fig,ax = plt.subplots(figsize = (10, 10))
ax.imshow(img)

rect_face = patches.Rectangle((x, y), w, h, 
                             linewidth = 5, 
                             edgecolor = 'r',
                             facecolor = 'none')
ax.add_patch(rect_face)

plt.text(10, 400, annotation, wrap=True, fontsize = 17, color = 'white')
plt.show()

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize = (10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴 인식, 나이 예측, 감정 분석

import requests  # 인터넷 연결

client_id = "pXfdBkFikDiBS8_MgcYQ"
client_secret = "j53WxUOyKj"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 275,
#             "height": 183
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 114,
#                 "y": 56,
#                 "width": 20,
#                 "height": 20
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999725
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.242592
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.684828
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.92016
#             }
#         },
#         {
#             "roi": {
#                 "x": 162,
#                 "y": 25,
#                 "width": 25,
#                 "height": 25
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 171,
#                     "y": 32
#                 },
#                 "rightEye": {
#                     "x": 180,
#                     "y": 32
#                 },
#                 "nose": {
#                     "x": 174,
#                     "y": 38
#                 },
#                 "leftMouth": {
#                     "x": 170,
#                     "y": 42
#                 },
#                 "rightMouth": {
#                     "x": 180,
#                     "y": 42
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.996792
#             },
#             "age": {
#                 "value": "25~29",
#                 "confidence": 0.950213
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.545195
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.824289
#             }
#         },
#         {
#             "roi": {
#                 "x": 85,
#                 "y": 40,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999752
#             },
#             "age": {
#                 "value": "26~30",
#                 "confidence": 0.387025
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.995412
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.837702
#             }
#         },
#         {
#             "roi": {
#                 "x": 154,
#                 "y": 68,
#                 "width": 23,
#                 "height": 23
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.995583
#             },
#             "age": {
#                 "value": "13~17",
#                 "confidence": 0.095429
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.59278
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.950124
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)


for each in parsed['faces']:
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                                 linewidth = 5,
                                 edgecolor = 'r',
                                 facecolor = 'none')
    ax.add_patch(rect_face)    
                                 
    annotation = gender + " : " + str(round(gen_confi, 3)*100)+"%" + '\n' + emotion + " : " + str(round(emotion_confi, 3)*100) + "%" +'\n' + age + " : " + str(round(age_confi, 3)*100) + "%"
    
    plt.text(x-10, y-10, annotation, wrap=True, fontsize = 10, color = 'blue')
                       

plt.show()

# %%
# 얼굴 인식, 나이 예측, 감정 분석

img = mpimg.imread('super.jpg')

plt.figure(figsize = (50, 50))
plt.imshow(img)
plt.show()

import requests  # 인터넷 연결

client_id = "pXfdBkFikDiBS8_MgcYQ"
client_secret = "j53WxUOyKj"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('super.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 307,
#             "height": 164
#         },
#         "faceCount": 7
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 35,
#                 "y": 32,
#                 "width": 19,
#                 "height": 19
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.997088
#             },
#             "age": {
#                 "value": "14~18",
#                 "confidence": 0.0264127
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.99918
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.776095
#             }
#         },
#         {
#             "roi": {
#                 "x": 135,
#                 "y": 30,
#                 "width": 18,
#                 "height": 18
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 139,
#                     "y": 33
#                 },
#                 "rightEye": {
#                     "x": 147,
#                     "y": 33
#                 },
#                 "nose": {
#                     "x": 143,
#                     "y": 37
#                 },
#                 "leftMouth": {
#                     "x": 139,
#                     "y": 41
#                 },
#                 "rightMouth": {
#                     "x": 146,
#                     "y": 41
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.568961
#             },
#             "age": {
#                 "value": "35~39",
#                 "confidence": 0.104919
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.694426
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.376867
#             }
#         },
#         {
#             "roi": {
#                 "x": 71,
#                 "y": 37,
#                 "width": 18,
#                 "height": 18
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.99362
#             },
#             "age": {
#                 "value": "31~35",
#                 "confidence": 0.309047
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.985172
#             },
#             "pose": {
#                 "value": "right_face",
#                 "confidence": 0.875107
#             }
#         },
#         {
#             "roi": {
#                 "x": 105,
#                 "y": 34,
#                 "width": 16,
#                 "height": 16
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.81872
#             },
#             "age": {
#                 "value": "48~52",
#                 "confidence": 0.169162
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.610583
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.611208
#             }
#         },
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 35,
#                 "width": 17,
#                 "height": 17
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.998762
#             },
#             "age": {
#                 "value": "33~37",
#                 "confidence": 0.0594889
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.983597
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.655217
#             }
#         },
#         {
#             "roi": {
#                 "x": 258,
#                 "y": 30,
#                 "width": 21,
#                 "height": 21
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.993425
#             },
#             "age": {
#                 "value": "21~25",
#                 "confidence": 0.197753
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.947399
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.543251
#             }
#         },
#         {
#             "roi": {
#                 "x": 206,
#                 "y": 41,
#                 "width": 17,
#                 "height": 17
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.904595
#             },
#             "age": {
#                 "value": "64~68",
#                 "confidence": 0.0321664
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.785607
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.740052
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('super.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)


for each in parsed['faces']:
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                                 linewidth = 5,
                                 edgecolor = 'r',
                                 facecolor = 'none')
    ax.add_patch(rect_face)    
                                 
    annotation = gender + " : " + str(round(gen_confi, 3)*100)+"%" + '\n' + emotion + " : " + str(round(emotion_confi, 3)*100) + "%" +'\n' + age + " : " + str(round(age_confi, 3)*100) + "%"
    
    plt.text(x-10, y-10, annotation, wrap=True, fontsize = 10, color = 'blue')
                       

plt.show()
